# %%
import os
import pandas as pd

# %%
os.chdir('C:/Users/HARENB/Desktop/dishrack images/Train')

# %%
k = []
for f in os.listdir():
    f_name, f_ext, = os.path.splitext(f)
    if f_ext == '.jpg':
        jpeg_name = f_name+','
        k.append(jpeg_name)
        print(jpeg_name)
# Out:
# jpeg00000000_0000000004724D26,
# jpeg00000000_00000000051334EC,
# jpeg00000000_000000009350BB1B,
# jpeg00000001_0000000004726D8F,
# jpeg00000001_00000000051346AF,
# jpeg00000001_0000000093513953,
# jpeg00000002_0000000004727ACE,
# jpeg00000002_000000000513564F,
# jpeg00000002_0000000093515056,
# jpeg00000003_0000000004728D4C,
# jpeg00000003_000000000513664D,
# jpeg00000003_0000000093519994,
# jpeg00000004_0000000004729C11,
# jpeg00000004_00000000051372B1,
# jpeg00000004_000000009351AC32,
# jpeg00000005_000000000472AA69,
# jpeg00000005_0000000005138241,
# jpeg00000005_000000009351CC6C,
# jpeg00000006_000000000472BDD2,
# jpeg00000006_00000000051392BC,
# jpeg00000006_000000009351E439,
# jpeg00000007_000000000472CC1A,
# jpeg00000007_0000000005139F00,
# jpeg00000007_0000000093520A7E,
# jpeg00000008_000000000472DB5D,
# jpeg00000008_000000000513AE04,
# jpeg00000008_0000000093522375,
# jpeg00000009_000000000472F666,
# jpeg00000009_000000000513BA68,
# jpeg00000009_0000000093524A94,
# ...

# %%
#Use to find inbalance
x = 1
y = 1
for f in os.listdir():
    f_name, f_ext = os.path.splitext(f)
    if f_ext == '.jpg':
        print(f_name,f_ext,x)
        x+=1
    if f_ext == '.xml':
        print(f_name,f_ext,y)
        y+=1
# Out:
# jpeg00000000_0000000004724D26 .jpg 1
# jpeg00000000_0000000004724D26 .xml 1
# jpeg00000000_00000000051334EC .jpg 2
# jpeg00000000_00000000051334EC .xml 2
# jpeg00000000_000000009350BB1B .jpg 3
# jpeg00000000_000000009350BB1B .xml 3
# jpeg00000001_0000000004726D8F .jpg 4
# jpeg00000001_0000000004726D8F .xml 4
# jpeg00000001_00000000051346AF .jpg 5
# jpeg00000001_00000000051346AF .xml 5
# jpeg00000001_0000000093513953 .jpg 6
# jpeg00000001_0000000093513953 .xml 6
# jpeg00000002_0000000004727ACE .jpg 7
# jpeg00000002_0000000004727ACE .xml 7
# jpeg00000002_000000000513564F .jpg 8
# jpeg00000002_000000000513564F .xml 8
# jpeg00000002_0000000093515056 .jpg 9
# jpeg00000002_0000000093515056 .xml 9
# jpeg00000003_0000000004728D4C .jpg 10
# jpeg00000003_0000000004728D4C .xml 10
# jpeg00000003_000000000513664D .jpg 11
# jpeg00000003_000000000513664D .xml 11
# jpeg00000003_0000000093519994 .jpg 12
# jpeg00000003_0000000093519994 .xml 12
# jpeg00000004_0000000004729C11 .jpg 13
# ...

# %%
import time

# %% [markdown]
# ## Directory Testing

# %%
os.chdir(r'C:\Users\HARENB\Downloads')

# %%
_list = []
for file in os.listdir():
    file_name, file_extension = os.path.splitext(file)
    if '.' in file_extension:
        print(file_name, file_extension)
        if '_' in file_name:
            _list.append(file_name)
_list
# Out:
# Anaconda3-2019.03-Windows-x86_64 .exe
# DataReadyMap0 .py
# desktop .ini
# Everything you can do with a time series .ipynb
# Exercise_ Introduction .ipynb
# Final Stock Predictor. Kind of Useless .ipynb
# Git-2.22.0-64-bit .exe
# PASCAL_VOC .zip
# Py-DS-ML-Bootcamp-master .zip
# pycon-pandas-tutorial-1.0 .zip
# python-3.7.3 .exe
# Python-DS-Presentations .zip
# rossmann .tgz
# SQLEXPR_x64_ENU .exe
# SQLManagementStudio_x64_ENU .exe
# ['Anaconda3-2019.03-Windows-x86_64',
#  'Exercise_ Introduction',
#  'PASCAL_VOC',
#  'SQLEXPR_x64_ENU',
#  'SQLManagementStudio_x64_ENU']

# %%
klist = []
for index in range(len(SQL)):
    k = SQL[index].split('_')
    klist.append(k)
klist
# Out:
# [['Anaconda3-2019.03-Windows-x86', '64'],
#  ['Exercise', ' Introduction'],
#  ['PASCAL', 'VOC'],
#  ['SQLEXPR', 'x64', 'ENU'],
#  ['SQLManagementStudio', 'x64', 'ENU']]

# %% [markdown]
# ## Renaming .jpgs

# %%
#First Test
l1 = []
l2 = []
l3 = []
x = 1

for f in os.listdir():
    if '.jpg' in f:
        l1.append(f.split('_'))

for piece in range(len(l1)):
    l2.append(l1[piece][0])
    
for item in range(len(l2)):
    l3.append(l2[item]+'_'+str(x))
    x+=1

l3
# Out:
# ['jpeg00000000_1',
#  'jpeg00000000_2',
#  'jpeg00000000_3',
#  'jpeg00000001_4',
#  'jpeg00000001_5',
#  'jpeg00000001_6',
#  'jpeg00000002_7',
#  'jpeg00000002_8',
#  'jpeg00000002_9',
#  'jpeg00000003_10',
#  'jpeg00000003_11',
#  'jpeg00000003_12',
#  'jpeg00000004_13',
#  'jpeg00000004_14',
#  'jpeg00000004_15',
#  'jpeg00000005_16',
#  'jpeg00000005_17',
#  'jpeg00000005_18',
#  'jpeg00000006_19',
#  'jpeg00000006_20',
#  'jpeg00000006_21',
#  'jpeg00000007_22',
#  'jpeg00000007_23',
#  'jpeg00000007_24',
#  'jpeg00000008_25',
#  'jpeg00000008_26',
#  'jpeg00000008_27',
#  'jpeg00000009_28',
#  'jpeg00000009_29',
#  'jpeg00000009_30',
#  'jpeg00000010_31',
#  'jpeg00000010_32',
#  'jpeg00000010_33',
#  'jpeg00000011_34',
#  'jpeg00000011_35',
#  'jpeg00000011_36',
#  'jpeg00000012_37',
#  'jpeg00000012_38',
#  'jpeg00000012_39',
#  'jpeg00000013_40',
#  'jpeg00000013_41',
#  'jpeg00000013_42',
#  'jpeg00000014_43',
#  'jpeg00000014_44',
#  'jpeg00000014_45',
# ...

# %%
#Cleaning up code. different, but gets the same point across
l1, l2, l3, x = [], [], [], 1
x1, x2, x3, y = [], [], [], 1

for k in os.listdir():
    if '.jpg' in k and '00000' in k:
        k = 'jpg'
        l1.append(k.split('_'))
        l2.append(l1[0][0])
        l3.append(l2[0]+'_'+str(x))
        x+=1
    if '.xml' in k:
        k = 'xml'
        x1.append(k.split('_'))
        x2.append(x1[0][0])
        x3.append(x2[0]+'_'+str(y))
        y+=1
        
for item in range(len(l3)):
    print(l3[item], x3[item])
# Out:
# jpg_1 xml_1
# jpg_2 xml_2
# jpg_3 xml_3
# jpg_4 xml_4
# jpg_5 xml_5
# jpg_6 xml_6
# jpg_7 xml_7
# jpg_8 xml_8
# jpg_9 xml_9
# jpg_10 xml_10
# jpg_11 xml_11
# jpg_12 xml_12
# jpg_13 xml_13
# jpg_14 xml_14
# jpg_15 xml_15
# jpg_16 xml_16
# jpg_17 xml_17
# jpg_18 xml_18
# jpg_19 xml_19
# jpg_20 xml_20
# jpg_21 xml_21
# jpg_22 xml_22
# jpg_23 xml_23
# jpg_24 xml_24
# jpg_25 xml_25
# jpg_26 xml_26
# jpg_27 xml_27
# jpg_28 xml_28
# jpg_29 xml_29
# jpg_30 xml_30
# jpg_31 xml_31
# jpg_32 xml_32
# jpg_33 xml_33
# jpg_34 xml_34
# jpg_35 xml_35
# jpg_36 xml_36
# jpg_37 xml_37
# jpg_38 xml_38
# jpg_39 xml_39
# jpg_40 xml_40
# jpg_41 xml_41
# jpg_42 xml_42
# jpg_43 xml_43
# jpg_44 xml_44
# jpg_45 xml_45
# jpg_46 xml_46
# jpg_47 xml_47
# jpg_48 xml_48
# jpg_49 xml_49
# jpg_50 xml_50
# jpg_51 xml_51
# jpg_52 xml_52
# jpg_53 xml_53
# jpg_54 xml_54
# jpg_55 xml_55
# jpg_56 xml_56
# jpg_57 xml_57
# jpg_58 xml_58
# jpg_59 xml_59
# jpg_60 xml_60
# jpg_61 xml_61
# jpg_62 xml_62
# jpg_63 xml_63
# ...
